# %%
import pandas as pd

# %% [markdown]
# # Inspect Data

# %%
hospital_data = pd.read_csv('/Users/giftdavid/Desktop/hospital_etl_pipeline/data/hospital.csv')
hospital_data.head()
# Out:
#   patient_id       patient_name  age  gender              sickness  \
# 0   PAT00001    Elizabeth Cline    9  Female                 Mumps
# 1   PAT00002           Jay Hall   13    Male  Peptic Ulcer Disease
# 2   PAT00003         Kyle Grant   12  Female          Dengue Fever
# 3   PAT00004  Jennifer Reynolds   50  Female                 Lupus
# 4   PAT00005       Valerie Hunt    2    Male  Macular Degeneration
#
#    visit_date admission_date  \
# 0  2023-06-15            NaN
# 1  2017-11-03            NaN
# 2  2019-02-02            NaN
# 3  2023-05-27            NaN
# 4         NaN            NaN
#
#                                        doctor_report  \
# 0  Patient was diagnosed with Otitis Media on 202...
# 1  Patient was diagnosed with Leishmaniasis on 20...
# 2  Patient was diagnosed with Tetanus Neonatorum ...
# 3  Patient was diagnosed with Monkeypox on 2023-0...
# 4  Patient was diagnosed with Mumps on Unknown. T...
#
#             treatment_status
# ...

# %%
hospital_data.shape
# Out:
# (1000, 9)

# %%
hospital_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   patient_id        1000 non-null   object
#  1   patient_name      955 non-null    object
#  2   age               1000 non-null   int64
#  3   gender            983 non-null    object
#  4   sickness          1000 non-null   object
#  5   visit_date        946 non-null    object
#  6   admission_date    189 non-null    object
#  7   doctor_report     1000 non-null   object
#  8   treatment_status  1000 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 70.4+ KB

# %%
hospital_data.nunique()
# Out:
# patient_id          1000
# patient_name         949
# age                  101
# gender                 2
# sickness             105
# visit_date           907
# admission_date       185
# doctor_report        991
# treatment_status       3
# dtype: int64

# %%
hospital_data.describe()
# Out:
#                age
# count  1000.000000
# mean     42.223000
# std      25.824837
# min       0.000000
# 25%      21.000000
# 50%      40.000000
# 75%      60.250000
# max     100.000000

# %%
hospital_data.isnull().sum()
# Out:
# patient_id            0
# patient_name         45
# age                   0
# gender               17
# sickness              0
# visit_date           54
# admission_date      811
# doctor_report         0
# treatment_status      0
# dtype: int64

# %%
hospital_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # EDA
